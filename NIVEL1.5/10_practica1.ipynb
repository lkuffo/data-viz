# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/comparasion_algoritmos.csv')
df
# Out:
#            dataset  algoritmo1  algoritmo2
# 0        City-Temp       24.17       22.92
# 1        Stocks-UK       21.51       16.70
# 2       Stocks-USA       19.22       12.06
# 3        Stocks-DE       20.78       13.46
# 4      IR-bio-temp       22.90       18.94
# 5         Wind-dir       28.15       19.80
# 6        PM10-dust       19.92       13.68
# 7   Dew-Point-Temp       39.03       32.49
# 8     Air-Pressure       27.89       19.23
# 9       Basel-wind       48.87       45.65
# 10      Basel-temp       36.51       30.12
# 11   Bitcoin-price       57.08       47.17
# 12  Bird-migration       35.94       28.37
# 13      Air-sensor       63.43       49.56
# 14     Food-prices       28.31       24.59
# 15         POI-lat       71.73       47.71
# 16        POI-Llon       75.89       54.55
# 17   Blockchain-tr       62.60       53.16
# 18        SD-bench       23.04       17.00

# %%
ax = df.plot(
    kind='bar',
    x='dataset',
    y=['algoritmo1', 'algoritmo2'],
    figsize=(12, 5)
)

ax.grid(visible=True)
ax.set_xlabel("Dataset")
ax.set_ylabel("Rendimiento")
ax.set_title("Evaluación de Algoritmo1 vs Algoritmo2")
ax.legend(labels=['Algoritmo 1', 'Algoritmo 2'], loc='upper left', bbox_to_anchor=(0, 1))
ax.set_axisbelow(True)

# %%
import seaborn as sns

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]
  
X_axis = np.arange(len(X))
plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys')
plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.legend()
plt.show()

# %%
import seaborn as sns
import pandas as pd
  
X = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]

df = pd.DataFrame({
    'Groups': ['Group A', 'Group A', 'Group B', 'Group B', 'Group C', 'Group C', 'Group D', 'Group D'],
    'Sex': ['Girl', 'Boy', 'Girl', 'Boy', 'Girl', 'Boy', 'Girl', 'Boy'],
    'Number of Students': [10, 20, 20, 30, 20, 25, 40, 30]
})
  
    
sns.barplot(
    data=df, 
    x='Groups', 
    y='Number of Students', 
    hue='Sex'
)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 15
#       6 Zboys = [20,30,25,30]
#       8 df = pd.DataFrame({
#       9     'Groups': ['Group A', 'Group A', 'Group B', 'Group B', 'Group C', 'Group C', 'Group D', 'Group D'],
#      10     'Sex': ['Girl', 'Boy', 'Girl', 'Boy', 'Girl', 'Boy', 'Girl', 'Boy'],
#      11     'Number of Students': [10, 20, 20, 30, 20, 25, 40, 30]
#      12 })
# ---> 15 sns.barplot(
#      16     data=df,
#      17     x='Groups',
#      18     y='Number of Students',
#      19     hue='Sex',
#      20     title='Number of Students in each Group'
#      21 )
#      24 plt.show()
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:1586, in _BarPlotter.plot(self, ax, bar_kws)
#    1584 def plot(self, ax, bar_kws):
#    1585     """Make the plot."""
# -> 1586     self.draw_bars(ax, bar_kws)
#    1587     self.annotate_axes(ax)
#    1588     if self.orient == "h":
#
# File /opt/homebrew/lib/python3.11/site-packages/seaborn/categorical.py:1569, in _BarPlotter.draw_bars(self, ax, kws)
#    1565 for j, hue_level in enumerate(self.hue_names):
#    1566
#    1567     # Draw the bars
#    1568     offpos = barpos + self.hue_offsets[j]
# -> 1569     barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1570             color=self.colors[j], align="center",
#    1571             label=hue_level, **kws)
#    1573     # Draw the confidence intervals
#    1574     if self.confint.size:
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2488, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2479 for l, b, w, h, c, e, lw, htch, lbl in args:
#    2480     r = mpatches.Rectangle(
#    2481         xy=(l, b), width=w, height=h,
#    2482         facecolor=c,
#    (...)
#    2486         hatch=htch,
#    2487         )
# -> 2488     r._internal_update(kwargs)
#    2489     r.get_path()._interpolation_steps = 100
#    2490     if orientation == 'vertical':
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File /opt/homebrew/lib/python3.11/site-packages/matplotlib/artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: Rectangle.set() got an unexpected keyword argument 'title'
