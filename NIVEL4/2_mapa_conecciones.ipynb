# %% [markdown]
# # Mapa de Conecciones
# Combina un Grafo con un Mapa de Puntos. Muestra en un espacio geográfico la distribución de puntos de interés y como existe una relación entre ellos. Si esta relación es direccional y codifica movimiento o flujo, se le denomina Mapa de Flujo. Para poder graficarlo necesito la posición geográfica de cada punto y la información sobre la conección entre cada punto (lista de ejes).
#
# ### Ejemplo de uso
# - Visualizar patrones de migración anuales
# - Patrones de exportación
# - Rutas aereas
# - Líneas de metro
#
# ![image-10.png](attachment:image-10.png)
#
# ### Consejos
# - Yo puedo calcular las mismas propiedades que tiene un grafo y aplicar las mismas tecnicas de graficación que en un grafo
# - Puedo introducir una variable al gráfico con las siguientes técticas:
#   - Diferente ancho de las conecciones para codificar una variable numérica
#   - Diferente color de las conecciones para codificar una variable numérica o categórica
# - No necesito algoritmos de posicionamiento de grafos, debido a que los puntos ya tienen un posicionamiento fijo en el mapa.
#
# ![image-11.png](attachment:image-11.png)
#
# ## En esta clase
# ### Datos
# Información sobre movimientos de surfistas a lo largo de diferentes paises del mundo
# ### Objetivos
# 1. Visualizar los movimientos de los surfistas
#
# ## Referencias
# - https://datavizcatalogue.com/ES/metodos/mapa_de_conexiones.html

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Algunos ambientes van a necesitar este modo para poder visualizar los graficos de Plotly
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %%
# Leemos los datos con Pandas
df = pd.read_csv('../data/viajes_surfistas.csv')
df = df.dropna()
df
# Out:
#                            homename  homecontinent               homecountry  \
# 0            Canadian in La La Land  North America  United States of America
# 1            Canadian in La La Land  North America  United States of America
# 2            Canadian in La La Land  North America  United States of America
# 3            Canadian in La La Land  North America  United States of America
# 4            Canadian in La La Land  North America  United States of America
# ...                             ...            ...                       ...
# 9506  Bridgetown, Western Australia      Australia                 Australia
# 9507                  Lille, France         Europe                    France
# 9508                             MX  South America                    Mexico
# 9509        Kuta - Bali - Indonesia           Asia                 Indonesia
# 9510        Kuta - Bali - Indonesia           Asia                 Indonesia
#
#         homelat     homelon travelcontinent             travelcountry  \
# 0     33.930030 -118.280993   North America  United States of America
# 1     33.930030 -118.280993   North America  United States of America
# 2     33.930030 -118.280993   North America  United States of America
# 3     33.930030 -118.280993   North America  United States of America
# 4     33.930030 -118.280993   North America  United States of America
# ...         ...         ...             ...                       ...
# 9506 -33.954448  116.131214       Australia                 Australia
# 9507  50.629250    3.057256          Europe                    France
# 9508  23.634501 -102.552784   South America                    Mexico
# 9509  -8.739184  115.171130            Asia                 Indonesia
# 9510  -8.739184  115.171130            Asia                 Indonesia
#
#       travellat   travellon
# 0     33.887255 -118.411912
# 1     34.022100 -118.481000
# 2     34.030400 -118.779000
# 3     33.887255 -118.411912
# 4     33.888889 -118.405278
# ...         ...         ...
# 9506 -34.225000  115.017000
# 9507  45.002343   -1.201475
# 9508  21.016700 -101.250000
# 9509  -8.710093  115.166845
# 9510  -8.710093  115.166845
#
# [9511 rows x 9 columns]

# %%
nodos_1 = df[['homecountry', 'homelat', 'homelon']]
nodos_1.columns = ['label', 'lat', 'lon']
nodos_1_agg = nodos_1.groupby(['lat', 'lon']).first()
nodos_1_agg = nodos_1_agg.reset_index()
nodos_1_agg
# Out:
#             lat         lon                     label
# 0    -53.773631  -67.707288                 Argentina
# 1    -51.733333  -72.516667                     Chile
# 2    -46.548628  -71.631977                 Argentina
# 3    -45.878760  170.502798               New Zealand
# 4    -44.885637  168.666159               New Zealand
# ...         ...         ...                       ...
# 1641  61.924110   25.748151                   Finland
# 1642  62.411363 -149.072971  United States of America
# 1643  63.264262   10.505392                    Norway
# 1644  64.200841 -149.493673  United States of America
# 1645  78.223172   15.626723                    Norway
#
# [1646 rows x 3 columns]

# %%
nodos_2 = df[['travelcountry', 'travellat', 'travellon']]
nodos_2.columns = ['label', 'lat', 'lon']
nodos_2_agg = nodos_2.groupby(['lat', 'lon']).first()
nodos_2_agg = nodos_2_agg.reset_index()
nodos_2_agg
# Out:
#             lat         lon        label
# 0    -51.055000  -72.832300        Chile
# 1    -46.592167  -70.932012    Argentina
# 2    -45.911490  170.490247  New Zealand
# 3    -45.911290  170.490020  New Zealand
# 4    -45.904483  170.510135  New Zealand
# ...         ...         ...          ...
# 4076  64.133300  -21.933300      Iceland
# 4077  68.077244   13.474686       Norway
# 4078  68.207469   14.480151       Norway
# 4079  68.659089   18.883573       Norway
# 4080  78.217424   15.636744       Norway
#
# [4081 rows x 3 columns]

# %%
nodos = pd.concat([nodos_1_agg, nodos_2_agg])
nodos = nodos.groupby(['lat', 'lon']).first()
nodos = nodos.reset_index()
nodos
# Out:
#             lat        lon      label
# 0    -53.773631 -67.707288  Argentina
# 1    -51.733333 -72.516667      Chile
# 2    -51.055000 -72.832300      Chile
# 3    -46.592167 -70.932012  Argentina
# 4    -46.548628 -71.631977  Argentina
# ...         ...        ...        ...
# 5720  68.077244  13.474686     Norway
# 5721  68.207469  14.480151     Norway
# 5722  68.659089  18.883573     Norway
# 5723  78.217424  15.636744     Norway
# 5724  78.223172  15.626723     Norway
#
# [5725 rows x 3 columns]

# %%
nodos['id'] = nodos.apply(lambda x: str(x.lat) + ',' + str(x.lon), axis=1)
nodos
# Out:
#             lat        lon      label                         id
# 0    -53.773631 -67.707288  Argentina    -53.7736313,-67.7072878
# 1    -51.733333 -72.516667      Chile      -51.733333,-72.516667
# 2    -51.055000 -72.832300      Chile           -51.055,-72.8323
# 3    -46.592167 -70.932012  Argentina  -46.59216709,-70.93201176
# 4    -46.548628 -71.631977  Argentina    -46.5486283,-71.6319773
# ...         ...        ...        ...                        ...
# 5720  68.077244  13.474686     Norway     68.07724353,13.4746857
# 5721  68.207469  14.480151     Norway    68.20746877,14.48015147
# 5722  68.659089  18.883573     Norway    68.65908859,18.88357262
# 5723  78.217424  15.636744     Norway    78.21742429,15.63674421
# 5724  78.223172  15.626723     Norway       78.2231722,15.626723
MzMzEzA9wKzQpF8TMA4MQMZKnNMwOiPH+D\u002fcUzA7\u002fj+H4ptTMD12JYBZ1ZMwCvVqgLaVkzAZohjXdxWTMCamZmZmVlMwPm7d9SYWEzAcuFASBZYTMAdoEUAgVhMwJqZmZmZWUzALlpfqOxITsDu68A5IwJNwNq5m22P+0zAwKofQCv6TMAuC9xwDvpMwKyt2F9290zAsHYU56jzTMBCzMqbaARNwNvcmJ6w+EzA\u002fhUJ2NT5TMAxZ2ye2ftMwAANJUnGOU3AL+HQWzxrTcDqu3T2QmtNwHAKKxVUVU3A\u002fF9kuPBOTcCdcdAU8D5NwFuAEY8fSE3A9\u002fjvh8AzTcDf\\u002foUSTcCCPHlgWRBQwLQI\u002fwEaEFDAhBieTX0MUMAN8VnoFAxQwKXPeVOyH1DAsCqxIe6+TsCI9rGC31ZPwCEf9GxWVU\u002fARzWRPlJqTcA="},"marker":{"color":"#636efa","size":4},"mode":"markers","name":"Argentina","showlegend":true,"subplot":"map","type":"scattermap"},{"hovertemplate":"label=Chile\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":{"dtype":"f8","bdata":"\u002fF7tAwGgEPOWoukDAcREpF3S6QMBwAEdMGrpAwHGBujd1uUDAX8\u002fXLJe4QMB3Pxt3UrhAwNvbLckBuEDAfDaCv6W3QMDrXKwDe7dAwPNOcHd3t0DAaLqNvGK3QMBHZIr\u002fXLZAwKRwPQrXs0DAJdSIcH6zQMAD3OLQEbNAwGWizv3RskDAsEbJ7Q+yQMDemo34wq9AwASr6uV3r0DA8UIh ...

# %%
lats = np.empty(len(df) * 2)
lats[::2] = df['homelat']
lats[1::2] = df['travellat']
lats[2::3] = None

lons = np.empty(len(df) * 2)
lons[::2] = df['homelon']
lons[1::2] = df['travellon']
lons[2::3] = None

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scattermap(
    mode = "markers+lines",
    lon = lons,
    lat = lats,
    marker = {
        'size': 5
    },
    line={
        'width': 1,
    },
    opacity=0.05
))

fig.update_layout(
    map = {
        'center': {'lon': 10, 'lat': 10},
        'style': "carto-darkmatter",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 1
    },
    showlegend = False,
    margin={"r":0,"t":0,"l":0,"b":0}
)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ee68b7ea-28b4-42df-bde4-0c8b2f6eb03b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ee68b7ea-28b4-42df-bde4-0c8b2f6eb03b")) {                    Plotly.newPlot(                        "ee68b7ea-28b4-42df-bde4-0c8b2f6eb03b",                        [{"lat":{"dtype":"f8","bdata":"a6XGOgv3QECeW42RkfFAQAAAAAAAAPh\u002f7Z48LNQCQUBrpcY6C\u002fdAQAAAAAAAAPh\u002fa6XGOgv3QECeW42RkfFAQAAAAAAAAPh\u002f8yl0HMfxQEDWqfI9Ix1HQAAAAAAAAPh\u002fiasUTEZXIcDKlCjedUwhwAAAAAAAAPh\u002f2NJI8Cs7GcB6UPXQ42JCQAAAAAAAAPh\u002felD10ONiQkCZnrDEAx5CQAAAAAAAAPh\u002fmZ6
3pP0CpSRGVHTZAQAAAAAAAAPh\u002fFK5H4XrEQUAUxVDz+lZBQAAAAAAAAPh\u002fFMVQ8\u002fpWQUBwrkjppVRBQAAAAAAAAPh\u002fJZVK9AkCQkC4UENlDdgSQAAAAAAAAPh\u002fuFBDZQ3YEkBmZmZmZmYSQAAAAAAAAPh\u002fZmZmZmZmEkC4UENlDdgSQAAAAAAAAPh\u002fuFBDZQ3YEkBmZmZmZmYSQAAAAAAAAPh\u002fZmZmZmZmEkC4UENlDdgSQAAAAAAAAPh\u002fuFBDZQ3YEkBMN4lBYIUSQAAAAAAAAPh\u002fZmZmZmZmEkC4UENlDdgSQAAAAAAAAPh\u002fKL41Cw\u002fyQUC2fMlrSiZCQAAAAAAAAPh\u002fG4Bwskv8QUAovjULD\u002fJBQAAAAAAAAPh\u002fJezbSUQEPMACznsxzm4hwAAAAAAAAPh\u002fO3DOiNL+QEBSms3jMONCQAAAAAAAAPh\u002fY3K09LKWQkA7ZV7cgF9CQAAAAAAAAPh\u002fO2Ve3IBfQkAio6jYPWlJQAAAAAAAAPh\u002fIqOo2D1pSUAy5q4l5GtJQAAAAAAAAPh\u002fqKEVMU9pSUBi72peekJFQAAAAAAAAPh\u002fYu9qXnpCRUA+Qf+QwBw8QAAAAAAAAPh\u002fnZblDEGLL0DWNf9UgW0+QAAAAAAAAPh\u002f1jX\u002fVIFtPkCmJkVUdog+QAAAAAAAAPh\u002fzpGu\u002fCZYQUD9LmzNVmhBQAAAAAAAAPh\u002fyCLyApHiQEBangd3Z+1AQAAAAAAAAPh\u002fsb\u002fsnjxcQEAnALUHEFtAQAAAAAAAAPh\u002fcYG6N3W5QMAEq+rld69AwAAAAAAAAPh\u002fgupZ77ukQkC7hnTTwaRCQAAAAAAAAPh\u002fu4Z008GkQkDrrBbYY6JCQAAAAAAAAPh\u002f66wW2GOiQkAjg9xFmM1HQAAAAAAAAPh\u002fI4PcRZjNR0CvJeSDns1HQAAAAAAAAPh\u002faETlNsz3QMCreCPzyE89QAAAAAAAAPh\u002fzLc+rDcaQkDZGyGov5VBQAAAAAAAAPh\u002fZKxXDRnzQMCsPx3q0kA\u002fwAAA ...

# %% [markdown]
# # Ejemplo adicional que añade colores a los puntos por una variable categórica

# %%
ejes = pd.DataFrame()
ejes['start_lat'] = df['homelat']
ejes['end_lat'] = df['travellat']
ejes['start_lon'] = df['homelon']
ejes['end_lon'] = df['travellon']
ejes['category'] = df['homecountry']
ejes['src'] = df.apply(lambda x: str(x.homelat) + ',' + str(x.homelon), axis=1)
ejes['dst'] = df.apply(lambda x: str(x.travellat) + ',' + str(x.travellon), axis=1)
ejes['count'] = 1
ejes = ejes.groupby(['src', 'dst']).agg({
    'count': 'count',
    'start_lat': 'first',
    'end_lat': 'first',
    'start_lon': 'first',
    'end_lon': 'first',
    'category': 'first'
})
ejes = ejes.sort_values(by='count')
ejes
# Out:
#                           src                        dst  count  start_lat  \
# 0         -0.023559,37.906193    -1.30858704,36.81370059      1  -0.023559
# 1     37.8857582,-122.1180201  38.53332971,-123.27718545      1  37.885758
# 2     37.9060368,-122.5449763  -28.02396037,153.38746213      1  37.906037
# 3     37.9060368,-122.5449763      23.316667,-102.366667      1  37.906037
# 4      37.9230693,139.2162435   37.76280911,139.01191815      1  37.923069
# ...                       ...                        ...    ...        ...
# 5117    34.975562,138.3827596   34.96330278,138.37420174     98  34.975562
# 5118  -33.9034863,151.2682338           -33.9036,151.268    101 -33.903486
# 5119  33.6189101,-117.9289469             33.6929,-118.0    137  33.618910
# 5120      39.399872,-8.224454         38.63333333,-9.225    143  39.399872
# 5121  34.0522342,-118.2436849  33.98906415,-118.46246481    481  34.052234
#
#         end_lat   start_lon     end_lon                  category
# 0     -1.308587   37.906193   36.813701                     Kenya
# 1     38.533330 -122.118020 -123.277185  United States of America
# 2    -28.023960 -122.544976  153.387462  United States of America
# 3     23.316667 -122.544976 -102.366667  United States of America
# 4     37.762809  139.216243  139.011918                     Japan
# ...         ...         ...         ...                       ...
# 5117  34.963303  138.382760  138.374202                     Japan
# 5118 -33.903600  151.268234  151.268000                 Australia
# 5119  33.692900 -117.928947 -118.000000  United States of America
# 5120  38.633333   -8.224454   -9.225000                  Portugal
# 5121  33.989064 -118.243685 -118.462465  United States of America
#
# [5122 rows x 8 columns]

# %%
# Mapa de Conecciones
# https://plotly.com/python/lines-on-mapbox/
# https://plotly.com/python-api-reference/generated/plotly.express.line_mapbox.html
# https://plotly.com/python/lines-on-maps/

# Hack para crear una separación entre cada linea.
lons = np.empty(3 * len(ejes))
lons[::3] = ejes['start_lon']
lons[1::3] = ejes['end_lon']
lons[2::3] = None # Si no hago esto, se va a formar un solo camino, en ves de ejes entre nodo y nodo

lats = np.empty(3 * len(ejes))
lats[::3] = ejes['start_lat']
lats[1::3] = ejes['end_lat']
lats[2::3] = None # Si no hago esto, se va a formar un solo camino, en ves de ejes entre nodo y nodo

# %%
# Lamentablemente en Plotly es complicado pintar las lineas de un diferente color
# Aqui una versión alternativa, pero con demasiados puntos (>500) no puede correr eficientemente

import random
map_colores = {}
base_colors = px.colors.qualitative.Light24
for cat in ejes['category']:
    if cat not in map_colores:
        color = random.choice(base_colors)
        map_colores[cat] = color
map_colores

ejes['colores'] = ejes['category'].apply(lambda x: map_colores[x])
ejes

colors = [""] * len(ejes) * 3
colors[::3] = ejes['colores']
colors[1::3] = ejes['colores']
colors[2::3] = ejes['colores']


fig_map = go.Figure()
i = 0
for idx, row in ejes.iterrows():
    start_lat = row.start_lat
    start_lon = row.start_lon
    end_lat = row.end_lat
    end_lon = row.end_lon
    
    lat = [start_lat, end_lat]
    lon = [start_lon, end_lon]
    
    fig_map.add_trace(
        go.Scattermap(
            lat = lat,
            lon = lon,
            mode = 'lines+markers',
            opacity= 0.08,
            marker={
                'size': 5,
                'color': row.colores,
            },
            line={
                'width': 1,
                'color': row.colores
            }
        )
    )
    i = i+1
    if i == 400:
        break

fig_map.update_layout(
    map = {
        'center': {'lon': 10, 'lat': 10},
        'style': "carto-darkmatter",
        'center': {'lon': -20, 'lat': -20},
        'zoom': 1
    },
    title_text = 'Movimiento de Surfistas',
    showlegend = False,
    margin={"r":0,"t":0,"l":0,"b":0}
)

fig_map
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ac337095-8eda-4e75-99f7-68a05099a76d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ac337095-8eda-4e75-99f7-68a05099a76d")) {                    Plotly.newPlot(                        "ac337095-8eda-4e75-99f7-68a05099a76d",                        [{"lat":[-0.023559,-1.30858704],"line":{"color":"#00B5F7","width":1},"lon":[37.906193,36.81370059],"marker":{"color":"#00B5F7","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.8857582,38.53332971],"line":{"color":"#6E899C","width":1},"lon":[-122.1180201,-123.27718545],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9060368,-28.02396037],"line":{"color":"#6E899C","width":1},"lon":[-122.5449763,153.38746213],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9060368,23.316667],"line":{"color":"#6E899C","width":1},"lon":[-122.5449763,-102.366667],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9230693,37.76280911],"line":{"color":"#479B55","width":1},"lon":[139.2162435,139.01191815],"marker":{"color":"#479B55","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9374939,22.08333333],"line":{"color":"#6E899C","width":1},"lon":[-107.8122852,-159.5],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9410884,36.71812],"line":{"color":"#EEA6FB","width":1},"lon":[-1.1357174,-4.40976],"marker":{"color":"#EEA6FB","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9621457,-23.67076],"line":{"color":"#6E899C","width":1},"lon":[-122.3455263,-46.54268],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9642529,37.966],"line":{"color":"#6E899C","width":1},"lon":[-91.8318334,-92.9722],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9642529,38.65282],"line":{"color":"#6E899C","width":1},"lon":[-91.8318334,-90.27216],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.979705,37.97955278],"line":{"color":"#E48F72","width":1},"lon":[23.737844,23.73791197],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9838096,37.86954185],"line":{"color":"#E48F72","width":1},"lon":[23.7275388,23.75809579],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9838096,37.99145929],"line":{"color":"#E48F72","width":1},"lon":[23.7275388,24.03036156],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9838096,37.99151147],"line":{"color":"#E48F72","width":1},"lon":[23.7275388,24.03045552],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9838096,37.9916146],"line":{"color":"#E48F72","width":1},"lon":[23.7275388,24.0304112],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.8715926,37.9026],"line":{"color":"#6E899C","width":1},"lon":[-122.272747,-122.645],"marker":{"color":"#6E899C","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[37.9838096,38.3],"line":{"color":"#E48F72","width":1},"lon":[23.7275388,23.7333],"marker":{"color":"#E48F72","size":5},"mode":"lines+markers","opacity":0.08,"type":"scattermap"},{"lat":[38.0951601,7.95614883],"line":{"color":"#EEA6FB","w ...
